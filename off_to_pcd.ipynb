# %%
## Instalaciones

# %pip install open3d
# %pip install plotly
# %pip install "notebook>=7.0" "anywidget>=0.9.13"

# %%
## Dependencias

import os
import shutil
from utils.transform import convert_off_to_pcd
from utils.plotter import notebook_plot_pcd
from random import choice

# %%
## Parametros y constantes

pcd_sample_size = 1024
categories = ["bathtub", "bed", "chair", "desk", "dresser", "monitor", "night_stand", "sofa", "table", "toilet"]
train_sizes = [106, 515, 889, 200, 200, 465, 200, 680, 392, 344]
test_sizes = [50, 100, 100, 86, 86, 100, 86, 100, 100, 100]

dataset_path = os.path.join("dataset")
off_path = os.path.join(dataset_path, "off")
pcd_path = os.path.join(dataset_path, "pcd")

# %%
## Crear carpeta 'dataset/pcd'

# Eliminar 'dataset/pcd'
if os.path.exists(pcd_path):
  confirmation = input(f"Confirm overwrite of '{pcd_path}'? (y/N)")
  if confirmation.lower() == "y":
    print(f"Overwriting folder '{pcd_path}'...")
    shutil.rmtree(pcd_path)
  else:
    print("Aborting...")
    raise Exception("The program was terminated prematurely by user request.")

# Crear 'dataset/pcd' con su estructura
os.makedirs(pcd_path)
for category in categories:
  os.makedirs(os.path.join(pcd_path, category))
  os.makedirs(os.path.join(pcd_path, category, "train"))
  os.makedirs(os.path.join(pcd_path, category, "test"))

# %%
## Transformar a point cloud

# Recorrer todo el dataset
for i in range(0, len(categories)):
  off_train_path = os.path.join(off_path, categories[i], "train")
  pcd_train_path = os.path.join(pcd_path, categories[i], "train")

  for j in range(1, train_sizes[i] + 1):
    index = str(j).zfill(4)
    off_obj = os.path.join(off_train_path, f"{categories[i]}_{index}.off")
    pcd_obj = os.path.join(pcd_train_path, f"{categories[i]}_{index}.pcd")
    convert_off_to_pcd(off_obj, pcd_obj, pcd_sample_size)

  off_test_path = os.path.join(off_path, categories[i], "test")
  pcd_test_path = os.path.join(pcd_path, categories[i], "test")

  for j in range(train_sizes[i] + 1, train_sizes[i] + test_sizes[i] + 1):
    index = str(j).zfill(4)
    off_obj = os.path.join(off_test_path, f"{categories[i]}_{index}.off")
    pcd_obj = os.path.join(pcd_test_path, f"{categories[i]}_{index}.pcd")
    convert_off_to_pcd(off_obj, pcd_obj, pcd_sample_size)

  print(f"'{categories[i]}' objects converted to .pcd")

# %%
## Visualizar point cloud

# Escoger aleatoriamente el objeto
category = choice(range(len(categories)))
train_or_test = choice(["train", "test"])
if train_or_test == "train":
  index = choice(range(1, train_sizes[category] + 1))
else:
  index = choice(range(train_sizes[category] + 1, train_sizes[category] + test_sizes[category] + 1))
obj = f"{categories[category]}_{str(index).zfill(4)}"
pcd_obj = os.path.join(pcd_path, categories[category], train_or_test, f"{obj}.pcd")
print(f"Visualizing file: {pcd_obj}")

# Visualizar el objeto escogido
notebook_plot_pcd(pcd_obj)
# Out:
# Visualizing file: dataset/pcd/chair/test/chair_0971.pcd
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="cf4d256a-d160-4526-9e11-938ecc3efdc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cf4d256a-d160-4526-9e11-938ecc3efdc6")) {                    Plotly.newPlot(                        "cf4d256a-d160-4526-9e11-938ecc3efdc6",                        [{"marker":{"size":1},"mode":"markers","x":{"dtype":"f8","bdata":"AAAAwID6IsAAAABAvc4RwAAAACBksiFAAAAAYMTIIMAAAADADMEWQAAAAACBnAtAAAAAAOhIEcAAAACAJesVQAAAAMD9FRHAAAAAQDA8J8AAAADg0scoQAAAAGCexg5AAAAAYPj4+D8AAAAgD2cowAAAAODMPSnAAAAAIFMuGsAAAADABAzSvwAAAIBAjRjAAAAAIA\u002fZE8AAAACgRlkZwAAAAAA+AyTAAAAAoL7HJMAAAAAAZfYnwAAAAEAJ1R5AAAAAAKLcK8AAAADAtPAsQAAAACB1kQTAAAAA4PaIJkAAAACAH7giwAAAAGDCUB7AAAAA4CIbHkAAAADA+IWDPwAAAKDp7B9AAAAAYLe+GMAAAAAALF4kwAAAAEAfaCZAAAAAIBoQJsAAAAAARHEPQAAAAKDO3STAAAAA4Ay2GcAAAAAggF\u002fzPwAAAMACcB9AAAAAQJ4lIEAAAACA+RkjwAAAAOC+EilAAAAAwG3LHkAAAAAgEir4PwAAACBP0RBAAAAAYFXG6D8AAACAcrYqQAAAAIDlDirAAAAAAI\u002f5HcAAAACAwRn\u002fPwAAAACm2gfAAAAAwJgwGcAAAABAZUkRwAAAACCPkxhAAAAA4K3WIUAAAAAAItnPPwAAACCmJghAAAAAwGovGUAAAADA8L0AQAAAAAAmhQpAAAAA4HrILEAAAADgy\u002fgrQAAAAGCGlh7AAAAAQNqqE0AAAACgfRwcwAAAAIAl5CRAAAAAQGbU+j8AAADg3H4QwAAAAEB4QM8\u002fAAAAoIQRH8AAAAAgGdwPwAAAAABPlAPAAAAAAG3TK0AAAAAgHdQUwAAAAIBkXQXAAAAAACTlK8AAAADAJGAfwAAAAEDIEwPAAAAAoES4vr8AAAAAEzgKwAAAACAbqyJAAAAAwFchGEAAAAAAVR0uQAAAAGAQQeS\u002fAAAAgBQQAEAAAACgg+0bQAAAAIDxCC1AAAAA4MYuJcAAAABgr+0swAAAAIAH8ArAAAAA4PTyDkAAAACgE0b4PwAAACD1gRbAAAAAgC32CUAAAADgVYMNwAAAAAA1\u002fy3AAAAA4DMZJkAAAABgofgTwAAAAGB2+SNAAAAA4PasD8AAAADg6hAowAAAAGCVOwrAAAAAANg06r8AAACgrwoiQAAAAKCQRRDAAAAAQCt6LEAAAADgBWkSwAAAAEBDDRRAAAAAIKL3EEAAAABgDnciwAAAAEAG\\u002fAAAAoFzj6r8AAAAAS38YwAAAAMA6QRHAAAAAgFlUGUAAAACAVS0TwAAAAMAmThXAAAAAAB37AMAAAABgwbgXQAAAAEB3VRfAAAAAoAJF4L8AAADgGQEXQAAAAKB8hyDAAAAAoI9neD8AAABgSJUgwAAAACCeZJe\u002fAAAAoDakIkAAAADAvkMEQAAAAID4Od8\u002fAAAAILpR+r8AAADAkhEVwAAAAMDm4RfAAAAAYKf\u002fF0AAAADgEVkVQAAAAEDFWAjAAAAAoHfE4D8AAABApwclQAAAAODUGSJAAAAAIE1OIcAAAABAqiAgwAAAAKC47CfAAAAAAOWbJEAAAABg5UkiwAAAACB8ZivAAAAAIEBMEUAAAABAsYgqwAAAAEDsLCXAAAAAwFWF378AAADg6yErQAAAAMB0RgBAAAAAAIFAFEAAAABAwa4hwAAAACDyt\u002fg\u002fAAAAoM4ELUAAAAAg1EUnwAAAAECB+itAAAAAQMqhKUAAAABAr+caQAAAAOB+tBlAAAAAwHthIEAAAACg97gnwAAAAOD7qyZAAAAAwKxOF0AAAAAAsfQUQAAAAIBuNSBAAAAAADbyI0AAAADgh6EDwAAAAGDb8BNAAAAAQDTXJ8AAAACgFYwCQAAAAEBmyyPAAAAAgDh\u002fAkAAAAAgHJ0qwAAAAED9gO0\u002fAAAAYN0WH8AAAADAhQQGQAAAAGDNMSfAAAAAIHupGkAAAAAAO7sdQAAAAKCVpQhAAAAAIB59EkAAAADADcceQAAAAOBWSPK\u002fAAAAgE7KH8AAAADAiAojwAAAAOAOuBPAAAAAIAuBIUAAAAAgN2EfQAAAAKBSdStAAAAAgOAvKUAAAABgX0gewAAAAGCzwSTAAAAAAFNsEkAAAABgV1v2vwAAACBJiPc\u002fAAAAQPNmIUAAAAAAoEwswAAAAMCBQNK\u002fAAAAwOvMJ8AAAAAgr0IcwAAAAEBi2CXAAAAAIH1CBMAAAADAYoIoQAAAAIAhixPAAAAAIO3DFUAAAADA8WAhwAAAAOA7OSHAAAAAQGZGCEAAAACApmHuPwAAAEByTSLAAAAAgIg\\u002fAAAAQGKC6T8AAACAvmIZwAAAACDAzOG\u002fAAAAAP63E8AAAADgNZMUwAAAACBXz+C\u002fAAAAQLuLCkAAAABgAAYRwAAAAEDV\u002fwRAAAAAgIfaDUAAAABA6q4Ew ...
